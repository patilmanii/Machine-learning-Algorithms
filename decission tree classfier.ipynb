# %%
import pandas

df = pandas.read_csv('comedian.csv')

print(df)
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
d = {'Uk' : 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

print(df)
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9          NaN   0
# 1    42          12     4          1.0   0
# 2    23           4     6          2.0   0
# 3    52           4     4          1.0   0
# 4    43          21     8          1.0   1
# 5    44          14     5          NaN   0
# 6    66           3     7          2.0   1
# 7    35          14     9          NaN   1
# 8    52          13     7          2.0   1
# 9    35           5     9          2.0   1
# 10   24           3     5          1.0   0
# 11   18           3     7          NaN   1
# 12   45           9     9          NaN   1

# %%
features = ['Age', 'Experience', 'Rank', 'Nationality']

x = df[features]
y = df['Go']

print(x)
print(y)
# Out:
#     Age  Experience  Rank  Nationality
# 0    36          10     9          NaN
# 1    42          12     4          1.0
# 2    23           4     6          2.0
# 3    52           4     4          1.0
# 4    43          21     8          1.0
# 5    44          14     5          NaN
# 6    66           3     7          2.0
# 7    35          14     9          NaN
# 8    52          13     7          2.0
# 9    35           5     9          2.0
# 10   24           3     5          1.0
# 11   18           3     7          NaN
# 12   45           9     9          NaN
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# Name: Go, dtype: int64

# %%
import pandas
from sklearn import tree
from sklearn.tree  import DecisionTreeClassifier
import matplotlib.pyplot as plt

df = pandas.read_csv("comedian.csv")

d = {'Uk' : 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

features = ['Age', 'Experience', 'Rank', 'Nationality']

x = df[features]
y = df['Go']

dtree = DecisionTreeClassifier()
dtree = dtree.fit(x, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.4444444444444444, 0.875, 'Rank <= 6.5\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.2222222222222222, 0.625, 'Nationality <= 1.5\ngini = 0.32\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1111111111111111, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6666666666666666, 0.625, 'Age <= 35.5\ngini = 0.375\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.5555555555555556, 0.375, 'gini = -0.889\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7777777777777778, 0.375, 'Age <= 39.5\ngini = 0.48\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.6666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8888888888888888, 0.125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]
